# %%
import tensorflow as tf
import numpy as np

# %%
filename = 'images//1.jpg'

# %% [markdown]
# ### Methods to load an image

# %%
from IPython.display import Image
Image(filename = 'images//1.jpg',width=224,height=224)

# %% [markdown]
# ### Another method to load Image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# ## Using open cv to load Image

# %%
import cv2

# %%
imgg =  cv2.imread(filename)
imgg = cv2.resize(imgg,(224,224))

# %%
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGB))

# %% [markdown]
# ### Last Method to load an Image

# %%
from PIL import Image

# %%
image = Image.open(filename)
image = image.resize((224,224))
plt.imshow(image)

# %% [markdown]
# ### Load the Deep Learning Model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()

# %% [markdown]
# ### Pre-Processing of the Image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# ### Finding the Cat Breed

# %%
predictions = mobile.predict(final_image)
from tensorflow.keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions)
print(results)
# Out:
# [[('n02123045', 'tabby', 0.839863), ('n02124075', 'Egyptian_cat', 0.09884709), ('n02123159', 'tiger_cat', 0.05859966), ('n02127052', 'lynx', 0.000978903), ('n04589890', 'window_screen', 0.0005568427)]]

# %%
filenames = 'images//100.jpg'

# %% [markdown]
# ### Method to load Image

# %% [markdown]
# #### Pre-Processing of the image

# %%
from tensorflow.keras.preprocessing import image
img123 = image.load_img(filenames, target_size = (224,224))

# %%
plt.imshow(img123)

# %%
resized_img = image.img_to_array(img123)
final_image = np.expand_dims(resized_img,axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
from tensorflow.keras.applications import imagenet_utils
results = imagenet_utils.decode_predictions(predictions)
print(results)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.52013034), ('n02087394', 'Rhodesian_ridgeback', 0.1905095), ('n02099849', 'Chesapeake_Bay_retriever', 0.092319354), ('n02093991', 'Irish_terrier', 0.050023805), ('n02090379', 'redbone', 0.042755324)]]

# %%
filenamess = 'images//101.jpg'

# %%
from tensorflow.keras.preprocessing import image
img1234 = image.load_img(filenamess, target_size = (224,224))

# %%
plt.imshow(img1234)

# %%
resized_img = image.img_to_array(img1234)
final_image = np.expand_dims(resized_img,axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)
